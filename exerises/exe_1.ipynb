# %% [markdown]
# ## Setup

# %%
# !pip -q install langchain langchain-community langchain-openai faiss-cpu tiktoken gradio

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Build RAG Micro-App

# %%
from langchain_openai import ChatOpenAI
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import OpenAIEmbeddings
from langchain_core.prompts import ChatPromptTemplate
import gradio as gr

texts = ["RAG grounds answers", "Hybrid retrieval helps", "Citations improve trust"]
vs = FAISS.from_texts(texts, OpenAIEmbeddings())
retriever = vs.as_retriever(k=2)
llm = ChatOpenAI(model="gpt-4o-mini")
prompt = ChatPromptTemplate.from_template(
    "Use context to answer and cite short quotes.\nContext: {context}\nQ: {q}"
)

def answer(q: str):
    docs = retriever.invoke(q)
    ctx = "\n".join(d.page_content for d in docs)
    return (prompt | llm).invoke({"context": ctx, "q": q}).content

ui = gr.Interface(fn=answer, inputs=gr.Textbox(label="Question"), outputs=gr.Markdown())
ui.launch()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/gy/v6xz068x1f9_ybg3xp_mq5lr0000gn/T/ipykernel_81848/3508669313.py in <module>
#       3 from langchain_community.embeddings import OpenAIEmbeddings
#       4 from langchain_core.prompts import ChatPromptTemplate
# ----> 5 import gradio as gr
#       6
#       7 texts = ["RAG grounds answers", "Hybrid retrieval helps", "Citations improve trust"]
#
# ~/Library/Python/3.9/lib/python/site-packages/gradio/__init__.py in <module>
#       1 import json
#       2
# ----> 3 import gradio._simple_templates
#       4 import gradio.image_utils
#       5 import gradio.processing_utils
#
# ~/Library/Python/3.9/lib/python/site-packages/gradio/_simple_templates/__init__.py in <module>
# ----> 1 from .simpledropdown import SimpleDropdown
#       2 from .simpleimage import SimpleImage
#       3 from .simpletextbox import SimpleTextbox
#       4
#       5 __all__ = ["SimpleDropdown", "SimpleTextbox", "SimpleImage"]
#
# ~/Library/Python/3.9/lib/python/site-packages/gradio/_simple_templates/simpledropdown.py in <module>
#       4 from typing import TYPE_CHECKING, Any, Callable, Sequence
#       5
# ----> 6 from gradio.components.base import Component, FormComponent
#       7 from gradio.events import Events
#       8
#
# ~/Library/Python/3.9/lib/python/site-packages/gradio/components/__init__.py in <module>
# ----> 1 from gradio.components.annotated_image import AnnotatedImage
#       2 from gradio.components.audio import Audio
#       3 from gradio.components.base import (
#       4     Component,
#       5     FormComponent,
#
# ~/Library/Python/3.9/lib/python/site-packages/gradio/components/annotated_image.py in <module>
#      12
#      13 from gradio import processing_utils, utils
# ---> 14 from gradio.components.base import Component
#      15 from gradio.data_classes import FileData, GradioModel
#      16 from gradio.events import Events
#
# ~/Library/Python/3.9/lib/python/site-packages/gradio/components/base.py in <module>
#      18
#      19 from gradio import utils
# ---> 20 from gradio.blocks import Block, BlockContext
#      21 from gradio.component_meta import ComponentMeta
#      22 from gradio.data_classes import BaseModel, DeveloperPath, GradioDataModel
#
# ~/Library/Python/3.9/lib/python/site-packages/gradio/blocks.py in <module>
#      37 from gradio_client.documentation import document
#      38
# ---> 39 from gradio import (
#      40     analytics,
#      41     components,
#
# ~/Library/Python/3.9/lib/python/site-packages/gradio/networking.py in <module>
#      13 import httpx
#      14
# ---> 15 from gradio.routes import App  # HACK: to avoid circular import # noqa: F401
#      16 from gradio.tunneling import Tunnel
#      17
#
# ~/Library/Python/3.9/lib/python/site-packages/gradio/routes.py in <module>
#      67
#      68 import gradio
# ---> 69 from gradio import ranged_response, route_utils, utils, wasm_utils
#      70 from gradio.context import Context
#      71 from gradio.data_classes import (
#
# ~/Library/Python/3.9/lib/python/site-packages/gradio/route_utils.py in <module>
#      51 )
#      52 from gradio.exceptions import Error
# ---> 53 from gradio.helpers import EventData
#      54 from gradio.state_holder import SessionState
#      55
#
# ~/Library/Python/3.9/lib/python/site-packages/gradio/helpers.py in <module>
#      24 from gradio_client.documentation import document
#      25
# ---> 26 from gradio import components, oauth, processing_utils, routes, utils, wasm_utils
#      27 from gradio.context import Context, LocalContext, get_blocks_context
#      28 from gradio.data_classes import GradioModel, GradioRootModel
#
# ~/Library/Python/3.9/lib/python/site-packages/gradio/oauth.py in <module>
#      11 import fastapi
#      12 from fastapi.responses import RedirectResponse
# ---> 13 from huggingface_hub import HfFolder, whoami
#      14
#      15 from .utils import get_space
#
# ImportError: cannot import name 'HfFolder' from 'huggingface_hub' (/Users/syedraza/Library/Python/3.9/lib/python/site-packages/huggingface_hub/__init__.py)
